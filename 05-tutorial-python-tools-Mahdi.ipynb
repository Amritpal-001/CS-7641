# %% [markdown]
# # Linear Algebra Operations
# ### [Markdown cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# $$\frac{a}{b}$$

# %%
import numpy as np
import numpy.random as nprd
import numpy.linalg as npla

# %% [markdown]
# #### [Python Lists vs. Numpy Arrays](https://webcourses.ucf.edu/courses/1249560/pages/python-lists-vs-numpy-arrays-what-is-the-difference)

# %%
python_list = [1,2,3]
python_nparray = np.array([1, 2, 3])
python_list, python_nparray
# Out:
# ([1, 2, 3], array([1, 2, 3]))

# %% [markdown]
# ## Vectors

# %% [markdown]
# #### Vector creation

# %%
x = np.array([1, 2, 3])
y = np.array([2, 4, 6])
x, y
# Out:
# (array([1, 2, 3]), array([2, 4, 6]))

# %% [markdown]
# #### Vector operation

# %%
np.sum(x)
# Out:
# 6

# %%
np.mean(x)
# Out:
# 2.0

# %%
np.std(x)
# Out:
# 0.816496580927726

# %%
np.dot(x, y)
# Out:
# 28

# %% [markdown]
# ## Matrices

# %% [markdown]
# #### Matrix Creation

# %%
A = np.array([[1, 2, 3], [1, 2, 3], [1, 2, 3]])
A
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
B = np.ones( (3, 3) )
B
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
R = nprd.random( (3, 3) )
R
# Out:
# array([[0.8265637 , 0.85643453, 0.15467901],
#        [0.08331715, 0.58009511, 0.20702015],
#        [0.77399916, 0.24626042, 0.71617934]])

# %% [markdown]
# #### Matrix Operation

# %%
A
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
A.T
# Out:
# array([[1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3]])

# %%
npla.inv(R)
# Out:
# array([[ 1.13504073, -1.7915108 ,  0.27271361],
#        [ 0.31317573,  1.47067542, -0.49275528],
#        [-1.3343632 ,  1.43044997,  1.27100288]])

# %%
x
# Out:
# array([1, 2, 3])

# %%
x.shape
x=x.reshape(3,1)
x.shape
# Out:
# (3, 1)

# %%
R.dot(x)
# Out:
# array([[3.00346979],
#        [1.8645678 ],
#        [3.41505803]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
B = B*2
B
# Out:
# array([[2., 2., 2.],
#        [2., 2., 2.],
#        [2., 2., 2.]])

# %%
C = A*B

# %%
np.sum(C)
# Out:
# 36.0

# %% [markdown]
# #### [What is Kernel](http://setosa.io/ev/image-kernels/)

# %% [markdown]
# ## Real Example
# #### Let's create an 8-bit grayscale bit-depth, 512 x 512 derived image for easy use in demos

# %%
import scipy.misc
import scipy
ascent = scipy.misc.ascent()
ascent
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
ascent.shape
# Out:
# (512, 512)

# %%
ascent.max()
# Out:
# 255

# %%
import matplotlib.pyplot as plt
plt.gray()
plt.imshow(ascent)
plt.show()

# %% [markdown]
# **Blur the image: for each pixel, replace the value to the average of its eight neighbors and itself**

# %%
F = np.ones((9, 9),np.float32) / 81
F
# Out:
# array([[0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568],
#        [0.01234568, 0.01234568, 0.01234568, 0.01234568, 0.01234568,
#         0.01234568, 0.01234568, 0.01234568, 0.01234568]], dtype=float32)

# %%
m, n = ascent.shape
blurred = np.zeros((m, n))

# %%
for i in range(4, m-4):
    for j in range(4, n-4):
        blurred[i][j] = np.sum(ascent[i-4:i+5, j-4:j+5] * F)

# %%
plt.imshow(blurred)
plt.show()

# %%
plt.imshow(blurred)
plt.show()

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Scatter Plot

# %%
x = nprd.random(1000)
y = nprd.random(1000)
plt.scatter(x, y)

# %% [markdown]
# #### Histogram

# %%
x = [1, 2, 2, 2, 3, 2, 1, 3, 2, 2, 4]
(4-1)/5
# Out:
# 0.75

# %%
plt.hist(x, bins=5)
# Out:
# (array([2., 6., 0., 2., 1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. ]),
#  <a list of 5 Patch objects>)

# %%
x = np.linspace(0, 10, 20)
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %% [markdown]
# #### Lines

# %%
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# #### Linepoints

# %%
plt.plot(x, np.sin(x), '-o')
plt.show()

# %% [markdown]
# #### Bars

# %%
x = np.linspace(0, 10, 10)
y = nprd.random(10)
plt.bar(x, y)
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %% [markdown]
# # Probability Distributions

# %% [markdown]
# ## Generate random samples

# %% [markdown]
# #### [Uniform Distribution](https://en.wikipedia.org/wiki/Discrete_uniform_distribution)

# %%
x = nprd.uniform(0, 1, 1000)
x.shape
# Out:
# (1000,)

# %%
plt.hist(x, 5)
# Out:
# (array([194., 196., 201., 209., 200.]),
#  array([0.00173344, 0.20063063, 0.39952783, 0.59842503, 0.79732222,
#         0.99621942]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# #### [Binomial Distribution](https://en.wikipedia.org/wiki/Binomial_distribution)

# %%
x = nprd.binomial(10, 0.7, 1000)

# %%
plt.hist(x, 20)
# Out:
# (array([  1.,   0.,   8.,   0.,   0.,  30.,   0., 116.,   0.,   0., 218.,
#           0., 262.,   0.,   0., 223.,   0., 113.,   0.,  29.]),
#  array([ 2. ,  2.4,  2.8,  3.2,  3.6,  4. ,  4.4,  4.8,  5.2,  5.6,  6. ,
#          6.4,  6.8,  7.2,  7.6,  8. ,  8.4,  8.8,  9.2,  9.6, 10. ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #### [Gaussian Distribution](https://en.wikipedia.org/wiki/Normal_distribution)

# %%
x = nprd.normal(1, 1.0, 1000)

# %% [markdown]
# #### [68–95–99.7 Rule](https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule)

# %%
plt.hist(x)
# Out:
# (array([  6.,  11.,  57., 131., 248., 254., 197.,  69.,  22.,   5.]),
#  array([-2.58112865, -1.87811513, -1.17510162, -0.4720881 ,  0.23092542,
#          0.93393894,  1.63695245,  2.33996597,  3.04297949,  3.74599301,
#          4.44900652]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 2D Gaussian
# $$ Covariance = \left( \begin{array}{ccc}  \sigma(x, x) & \sigma(x, y) \\  \sigma(y, x) & \sigma(y, y) \end{array} \right)$$

# %%
mean = [0, 0]
cov = [[1, 25], [25, 625]] 
x, y = nprd.multivariate_normal(mean, cov, 1000).T

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Estimate Parameters from Samples

# %%
x = nprd.normal(0, 1.0, 1000)

# %%
mu = np.mean(x)
sigma = np.std(x)
mu, sigma

# %%
count, bins, ignored = plt.hist(x, 40, normed=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),  linewidth=2, color='r')
plt.show()

# %%
bins
